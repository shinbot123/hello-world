# %%
import ms.version

ms.version.addpkg('numpy', '1.14.2')
ms.version.addpkg('pandas', '0.22.0')
ms.version.addpkg('dateutil', '2.7.2')
ms.version.addpkg('six', '1.11.0-ms1')
ms.version.addpkg('pytz', '2017.3')
ms.version.addpkg('matplotlib', '2.2.2')
ms.version.addpkg('pyparsing', '2.2.0')
ms.version.addpkg('cycler', '0.10.0')
ms.version.addpkg('kiwisolver', '1.0.1')
ms.version.addpkg('scipy', '1.0.0')
ms.version.addpkg('sklearn', '0.19b2')

import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
data = pd.read_csv('data.csv')
#X=data.iloc[:,[0,2]]
X=data.iloc[:,[0,1,2]]
y=data.iloc[:,[3]]

#print(data.iloc[[1:3],[0]])

# %%
#X.columns = ['yui','jkh']
#print(X)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression(fit_intercept=True)
reg.fit(X,y)
predy=reg.predict(X)
#xt = np.linspace(0.0, 1.0, num=1000).reshape((1000, 1))
#yt = reg.predict(xt)
plt.plot(X, y, 'o')
plt.plot(xt, yt)
plt.show()
from sklearn.metrics import mean_squared_error
mean_squared_error(y,predy)
# Out:
# {'normalize': False, 'copy_X': True, 'n_jobs': 1, 'fit_intercept': True}

# %%
poly = PolynomialFeatures(2)
Xpoly=poly.fit_transform(X)
reg.fit(Xpoly,y)
predy=reg.predict(Xpoly)

xt = np.linspace(0.0, 1.0, num=1000).reshape((1000, 1))
#print(xt)
#yt = reg.predict(xt)
#plt.plot(xt, yt, 'o')
#plt.plot(xt, yt)
plt.show()
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y,predy))
print(reg.coef_)
print(reg.intercept_)
# Out:
# 0.0002117594583642143
# [[ 0.00000000e+00 -1.97272077e+00 -7.38020608e-04  4.73691531e-03
#   -1.14005490e-02  4.17849877e-03  2.99893002e+00  5.00043522e+00
#    2.66520589e-04 -4.71329644e-04]]
# [2.9834251]
